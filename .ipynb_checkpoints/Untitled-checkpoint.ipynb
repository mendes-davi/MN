# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x) :
    return np.cos(np.sin(2*x) * np.exp(-x/4))

X = np.linspace(0,5,100)
X_=np.linspace(0,5,10)
X__=np.zeros(2 * len(X_) - 1)
X__[::2] = X_
X__[1::2] = X_[1:]
plt.plot(X_,f(X_),'ko-')
plt.show()
